# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenvo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Read data

df = pd.read_csv('C:\Datasets\Reviews.csv')

df = df.head(10000)
df.shape
# Out:
# (10000, 10)

# %%
df.head(10)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8   9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9  10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# ...

# %% [markdown]
# # Do a quick EDA

# %%
#df.shape
ax = df['Score'].value_counts().sort_index().plot(kind='bar', title="Review count by stars" , figsize=(10,5))

ax.set_xlabel(' Review by start')
plt.show()

# %% [markdown]
# # Basic NLTK

# %%
example = df['Text'][50]

print(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
token = nltk.word_tokenize(example)
token[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
nltk.download('averaged_perceptron_tagger')

tagged = nltk.pos_tag(token)
tagged[:10]
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\lenvo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
group_data = nltk.chunk.ne_chunk(tagged)
group_data.pprint()
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\lenvo\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\lenvo\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# # Sentiment Analysis
# Vader Sentiment Scoring

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
#nltk.download('all')
nltk.download('vader_lexicon')


sentiment_intensity_object = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\lenvo\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
sentiment_intensity_object

# %%
sentiment_intensity_object.polarity_scores("what am I doing here")
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sentiment_intensity_object.polarity_scores("This is worst place to be ")
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
#sentiment_intensity_object.polarity_scores("I am really happy for you.")

sentiment_intensity_object.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Run ploarity score on the entire dataset
res = {}
for i , row in tqdm(df.iterrows() , total = len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sentiment_intensity_object.polarity_scores(text)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
res
# Out:
# {1: {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.9441},
#  2: {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.5664},
#  3: {'neg': 0.091, 'neu': 0.754, 'pos': 0.155, 'compound': 0.8265},
#  4: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  5: {'neg': 0.0, 'neu': 0.552, 'pos': 0.448, 'compound': 0.9468},
#  6: {'neg': 0.029, 'neu': 0.809, 'pos': 0.163, 'compound': 0.883},
#  7: {'neg': 0.034, 'neu': 0.693, 'pos': 0.273, 'compound': 0.9346},
#  8: {'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.9487},
#  9: {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.6369},
#  10: {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.8313},
#  11: {'neg': 0.017, 'neu': 0.846, 'pos': 0.137, 'compound': 0.9746},
#  12: {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'compound': -0.7579},
#  13: {'neg': 0.031, 'neu': 0.923, 'pos': 0.046, 'compound': 0.296},
#  14: {'neg': 0.0, 'neu': 0.355, 'pos': 0.645, 'compound': 0.9466},
# ...

# %%
df
# Out:
#          Id   ProductId          UserId                      ProfileName  \
# 0         1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1         2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2         3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3         4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4         5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...     ...         ...             ...                              ...
# 9995   9996  B000P41A28  A3A63RACXR1XIL            A. Boodhoo "deaddodo"
# 9996   9997  B000P41A28    A5VVRGL8JA7R                             Adam
# 9997   9998  B000P41A28  A2TGDTJ8YCU6PD                          geena77
# 9998   9999  B000P41A28   AUV4GIZZE693O              Susan Coe "sueysis"
# 9999  10000  B000P41A28   A82WIMR4RSVLI                       Emrose mom
#
#       HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(df , how='left')

vaders
# Out:
#          Id    neg    neu    pos  compound   ProductId          UserId  \
# 0         1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1         2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2         3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3         4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4         5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
# ...     ...    ...    ...    ...       ...         ...             ...
# 9995   9996  0.089  0.852  0.059   -0.5267  B000P41A28  A3A63RACXR1XIL
# 9996   9997  0.091  0.747  0.162    0.6808  B000P41A28    A5VVRGL8JA7R
# 9997   9998  0.063  0.811  0.126    0.9305  B000P41A28  A2TGDTJ8YCU6PD
# 9998   9999  0.149  0.697  0.154    0.2809  B000P41A28   AUV4GIZZE693O
# 9999  10000  0.026  0.811  0.164    0.9850  B000P41A28   A82WIMR4RSVLI
#
#                           ProfileName  HelpfulnessNumerator  \
# ...

# %% [markdown]
# # Plot Vaders Results

# %%
ax = sns.barplot(data=vaders , x='Score' , y='compound')
ax.set_title("Score vs compound for amazon Review ")
plt.show()

# %%
fig , axs = plt.subplots(1 , 3, figsize=(12,3))
sns.barplot(data=vaders , x="Score" , y ='pos' , ax=axs[0])
sns.barplot(data=vaders , x="Score" , y ='neu' , ax=axs[1])
sns.barplot(data=vaders , x="Score" , y ='neg' , ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Netural')
axs[2].set_title('Negative')
plt.show()

# %% [markdown]
# # Roberta Pretrained Model
#
# Model Pretrained for large amounts of data
# Accounts for Words but also context releated to words

# %%
from transformers import AutoTokenizer
#from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
from transformers import RobertaForSequenceClassification
from transformers import AutoModelForSequenceClassification

# %%
model = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model)
model = AutoModelForSequenceClassification.from_pretrained(model)
# Out:
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# c:\Users\lenvo\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:147: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\lenvo\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
# Vader Result on example
print(example)
sentiment_intensity_object.polarity_scores(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Run Roberta Model
encoded_text = tokenizer(example , return_tensors='pt')
output = model(**encoded_text)
roberta_scores = output[0][0].detach().numpy()
roberta_scores = softmax(roberta_scores)
roberta_scores
# Out:
# array([0.97635514, 0.02068746, 0.00295737], dtype=float32)

# %%
scores_dict = {
        'roberta_neg' : roberta_scores[0],
        'roberta_neu' : roberta_scores[1],
        'roberta_pos' : roberta_scores[2]
}

print(scores_dict)
# Out:
# {'roberta_neg': 0.97635514, 'roberta_neu': 0.020687465, 'roberta_pos': 0.0029573692}

# %%
def polarity_scores_roberta (example):
    encoded_text = tokenizer(example , return_tensors='pt')
    output = model(**encoded_text)
    roberta_scores = output[0][0].detach().numpy()
    roberta_scores = softmax(roberta_scores)
    scores_dict = {
        'roberta_neg' : roberta_scores[0],
        'roberta_neu' : roberta_scores[1],
        'roberta_pos' : roberta_scores[2]
    }
    return  scores_dict

# %%
res_new = {}

for i , row in tqdm(df.iterrows(), total=len(df)):
    try :
    text = row['Text']
    myid = row['Id']
    vader_result = sentiment_intensity_object.polarity_scores(text)

    roberta_result = polarity_scores_roberta(text)
    both = {**vader_result , **roberta_result}
    res_new[myid] = both
    
    except RuntimeError:
        print("broke for id {myid}")
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 8
#       5 myid = row['Id']
#       6 vader_result = sentiment_intensity_object.polarity_scores(text)
# ----> 8 roberta_result = polarity_scores_roberta(text)
#       9 both = {**vader_result , **roberta_result}
#      10 res_new[myid] = both
#
# Cell In[31], line 3, in polarity_scores_roberta(example)
#       1 def polarity_scores_roberta (example):
#       2     encoded_text = tokenizer(example , return_tensors='pt')
# ----> 3     output = model(**encoded_text)
#       4     roberta_scores = output[0][0].detach().numpy()
#       5     roberta_scores = softmax(roberta_scores)
#
# File c:\Users\lenvo\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
# ...

# %%
print(both)
# Out:
# {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.9441, 'roberta_neg': 0.009624226, 'roberta_neu': 0.049980372, 'roberta_pos': 0.94039536}

# %%
results_df = pd.DataFrame(res_new).T
results_df = results_df.reset_index().rename(columns={'index' : 'Id'})
results_df = results_df.merge(df , how='left')
